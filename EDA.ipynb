# %%
import numpy as np
import re 
import pandas as pd
import matplotlib as mpl
import matplotlib.pyplot as plt
import seaborn as sns
import openpyxl

# %%
pip install -U scikit-learn
# Out:
# ...
# Note: you may need to restart the kernel to use updated packages.
# [notice] A new release of pip is available: 23.2.1 -> 23.3.2
# [notice] To update, run: python.exe -m pip install --upgrade pip

# %%
from ydata_profiling import ProfileReport

# %%
df = pd.read_excel('arch0.xlsx')
df
# Out:
#       Source.Name  TIPO DOCUMENTO NRO DOCUMENTO  CUIT - CUIL  GENERO  \
# 0        2018.txt               0      24684325  99999999999       2
# 1        2018.txt               0      35953009  99999999999       2
# 2        2018.txt               0      35953709  99999999999       1
# 3        2018.txt               0      36814158  99999999999       2
# 4        2018.txt               0      37575933  99999999999       1
# ...           ...             ...           ...          ...     ...
# 10880    2023.txt               0      40968435  99999999999       1
# 10881    2023.txt               0      40968490  99999999999       1
# 10882    2023.txt               0      41792889  99999999999       2
# 10883    2023.txt               0      42532620  99999999999       2
# 10884    2023.txt               0      43929133  99999999999       1
#
#        FECHA NACIMIENTO  CUE ESCUELA ORIGEN HORAS TRABAJO  \
# 0              19750209           999999999            NT
# ...

# %%
# Dimensions of our dataset
dimensions = df.shape
dimensions
# Out:
# (10885, 41)

# %%
# Data type of each atribute
data_types = df.dtypes
data_types
# Out:
# Source.Name                                       object
# TIPO DOCUMENTO                                     int64
# NRO DOCUMENTO                                     object
# CUIT - CUIL                                        int64
# GENERO                                             int64
# FECHA NACIMIENTO                                   int64
# CUE ESCUELA ORIGEN                                 int64
# HORAS TRABAJO                                     object
# COD NIVEL INSTRUCCION PADRE                        int64
# COD NIVEL INSTRUCCION MADRE                        int64
# COD PAIS NACIMIENTO                                int64
# COD PAIS PROCEDENCIA                               int64
# FECHA INGRESO AL PAIS                            float64
# COD PAIS QUE EXPIDE EL TITULO                      int64
# LOCALIDAD DE PROCEDENCIA                         float64
# AÑO ACADÉMICO                                      int64
# ...

# %%
# Statistical Summary
data_description = df.describe()
data_info = df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 10885 entries, 0 to 10884
# Data columns (total 41 columns):
#  #   Column                                  Non-Null Count  Dtype
# ---  ------                                  --------------  -----
#  0   Source.Name                             10885 non-null  object
#  1   TIPO DOCUMENTO                          10885 non-null  int64
#  2   NRO DOCUMENTO                           10885 non-null  object
#  3   CUIT - CUIL                             10885 non-null  int64
#  4   GENERO                                  10885 non-null  int64
#  5   FECHA NACIMIENTO                        10885 non-null  int64
#  6   CUE ESCUELA ORIGEN                      10885 non-null  int64
#  7   HORAS TRABAJO                           10885 non-null  object
#  8   COD NIVEL INSTRUCCION PADRE             10885 non-null  int64
#  9   COD NIVEL INSTRUCCION MADRE             10885 non-null  int64
# ...

# %%
#Columnas duplicadas
df.duplicated()
# Out:
# 0        False
# 1        False
# 2        False
# 3        False
# 4        False
#          ...
# 10880    False
# 10881    False
# 10882    False
# 10883    False
# 10884    False
# Length: 10885, dtype: bool

# %%
# Corroboremos si tenemos datos faltantes
df.isnull().sum()
# Out:
# Source.Name                                  0
# TIPO DOCUMENTO                               0
# NRO DOCUMENTO                                0
# CUIT - CUIL                                  0
# GENERO                                       0
# FECHA NACIMIENTO                             0
# CUE ESCUELA ORIGEN                           0
# HORAS TRABAJO                                0
# COD NIVEL INSTRUCCION PADRE                  0
# COD NIVEL INSTRUCCION MADRE                  0
# COD PAIS NACIMIENTO                          0
# COD PAIS PROCEDENCIA                         0
# FECHA INGRESO AL PAIS                     5668
# COD PAIS QUE EXPIDE EL TITULO                0
# LOCALIDAD DE PROCEDENCIA                  1207
# AÑO ACADÉMICO                                0
# latitud localidad                         2100
# longitud localidad                        2100
# latitud dpto                              1285
# longitud dpto                             1285
# ...

# %%
df = pd.read_excel('arch1.xlsx')
df
# Out:
#       Source.Name  TIPO DOCUMENTO NRO DOCUMENTO  CUIT - CUIL  \
# 0        2017.txt               0      37797716  99999999999
# 1        2017.txt               0      40556955  99999999999
# 2        2017.txt               0      13224482  99999999999
# 3        2017.txt               0      35292027  99999999999
# 4        2017.txt               0      41319684  99999999999
# ...           ...             ...           ...          ...
# 15528    2023.txt               0      37547773  23375477734
# 15529    2023.txt               0      41287998  27412879983
# 15530    2023.txt               0      41602052  27416020529
# 15531    2023.txt               0      41732160  20417321609
# 15532    2023.txt               0      40266584  27402665845
#
#        COD UNIDAD ACADEMICA  COD TITULO  AÑO DE INGRESO  FORMA DE INGRESO  \
# 0                      3173         598            2017                 1
# 1                      3173         598            2017                 1
# ...

# %%
# Dimensions of our dataset
dimensions = df.shape
dimensions
# Out:
# (15533, 46)

# %%
# Data type of each atribute
data_types = df.dtypes
data_types
# Out:
# Source.Name                                 object
# TIPO DOCUMENTO                               int64
# NRO DOCUMENTO                               object
# CUIT - CUIL                                  int64
# COD UNIDAD ACADEMICA                         int64
# COD TITULO                                   int64
# AÑO DE INGRESO                               int64
# FORMA DE INGRESO                             int64
# FECHA DE EGRESADO                          float64
# DEPENDENCIA DE INGRESO                       int64
# DEPENDENCIA DE EGRESO                      float64
# Año Académico                                int64
# titulo araucano                             object
# EGRESADO                                    object
# título - nombre corto                       object
# AÑO EGRESADO - TITULO                       object
# AÑO-DNI                                     object
# Escuela de Origen                           object
# ...

# %%
# Statistical Summary
data_description = df.describe()
data_info = df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 15533 entries, 0 to 15532
# Data columns (total 46 columns):
#  #   Column                                   Non-Null Count  Dtype
# ---  ------                                   --------------  -----
#  0   Source.Name                              15533 non-null  object
#  1   TIPO DOCUMENTO                           15533 non-null  int64
#  2   NRO DOCUMENTO                            15533 non-null  object
#  3   CUIT - CUIL                              15533 non-null  int64
#  4   COD UNIDAD ACADEMICA                     15533 non-null  int64
#  5   COD TITULO                               15533 non-null  int64
#  6   AÑO DE INGRESO                           15533 non-null  int64
#  7   FORMA DE INGRESO                         15533 non-null  int64
#  8   FECHA DE EGRESADO                        289 non-null    float64
#  9   DEPENDENCIA DE INGRESO                   15533 non-null  int64
# ...

# %%
#Columnas duplicadas
df.duplicated()
# Out:
# 0        False
# 1        False
# 2        False
# 3        False
# 4        False
#          ...
# 15528    False
# 15529    False
# 15530    False
# 15531    False
# 15532    False
# Length: 15533, dtype: bool

# %%
# Corroboremos si tenemos datos faltantes
df.isnull().sum()
# Out:
# Source.Name                                    0
# TIPO DOCUMENTO                                 0
# NRO DOCUMENTO                                  0
# CUIT - CUIL                                    0
# COD UNIDAD ACADEMICA                           0
# COD TITULO                                     0
# AÑO DE INGRESO                                 0
# FORMA DE INGRESO                               0
# FECHA DE EGRESADO                          15244
# DEPENDENCIA DE INGRESO                         0
# DEPENDENCIA DE EGRESO                      15244
# Año Académico                                  0
# titulo araucano                                0
# EGRESADO                                   15244
# título - nombre corto                          0
# AÑO EGRESADO - TITULO                          0
# AÑO-DNI                                        0
# Escuela de Origen                           4839
# Edad durante el año académico                493
# ...

# %%
df = pd.read_excel('arch2.xlsx')
df
# Out:
#       Source.Name  TIPO DOCUMENTO NRO DOCUMENTO  CUIT - CUIL  \
# 0        2017.txt               0      37797716  99999999999
# 1        2017.txt               0      40556955  99999999999
# 2        2017.txt               0      13224482  99999999999
# 3        2017.txt               0      35292027  99999999999
# 4        2017.txt               0      41319684  99999999999
# ...           ...             ...           ...          ...
# 15528    2023.txt               0      37547773  23375477734
# 15529    2023.txt               0      41287998  27412879983
# 15530    2023.txt               0      41602052  27416020529
# 15531    2023.txt               0      41732160  20417321609
# 15532    2023.txt               0      40266584  27402665845
#
#        COD UNIDAD ACADEMICA  COD TITULO  AÑO DE INGRESO  FORMA DE INGRESO  \
# 0                      3173         598            2017                 1
# 1                      3173         598            2017                 1
# ...

# %%
# Dimensions of our dataset
dimensions = df.shape
dimensions
# Out:
# (15533, 46)

# %%
# Data type of each atribute
data_types = df.dtypes
data_types
# Out:
# Source.Name                                 object
# TIPO DOCUMENTO                               int64
# NRO DOCUMENTO                               object
# CUIT - CUIL                                  int64
# COD UNIDAD ACADEMICA                         int64
# COD TITULO                                   int64
# AÑO DE INGRESO                               int64
# FORMA DE INGRESO                             int64
# FECHA DE EGRESADO                          float64
# DEPENDENCIA DE INGRESO                       int64
# DEPENDENCIA DE EGRESO                      float64
# Año Académico                                int64
# titulo araucano                             object
# EGRESADO                                    object
# título - nombre corto                       object
# AÑO EGRESADO - TITULO                       object
# AÑO-DNI                                     object
# Escuela de Origen                           object
# ...

# %%
# Statistical Summary
data_description = df.describe()
data_info = df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 15533 entries, 0 to 15532
# Data columns (total 46 columns):
#  #   Column                                   Non-Null Count  Dtype
# ---  ------                                   --------------  -----
#  0   Source.Name                              15533 non-null  object
#  1   TIPO DOCUMENTO                           15533 non-null  int64
#  2   NRO DOCUMENTO                            15533 non-null  object
#  3   CUIT - CUIL                              15533 non-null  int64
#  4   COD UNIDAD ACADEMICA                     15533 non-null  int64
#  5   COD TITULO                               15533 non-null  int64
#  6   AÑO DE INGRESO                           15533 non-null  int64
#  7   FORMA DE INGRESO                         15533 non-null  int64
#  8   FECHA DE EGRESADO                        289 non-null    float64
#  9   DEPENDENCIA DE INGRESO                   15533 non-null  int64
# ...

# %%
#Columnas duplicadas
df.duplicated()
# Out:
# 0        False
# 1        False
# 2        False
# 3        False
# 4        False
#          ...
# 15528    False
# 15529    False
# 15530    False
# 15531    False
# 15532    False
# Length: 15533, dtype: bool

# %%
# Corroboremos si tenemos datos faltantes
df.isnull().sum()
# Out:
# Source.Name                                    0
# TIPO DOCUMENTO                                 0
# NRO DOCUMENTO                                  0
# CUIT - CUIL                                    0
# COD UNIDAD ACADEMICA                           0
# COD TITULO                                     0
# AÑO DE INGRESO                                 0
# FORMA DE INGRESO                               0
# FECHA DE EGRESADO                          15244
# DEPENDENCIA DE INGRESO                         0
# DEPENDENCIA DE EGRESO                      15244
# Año Académico                                  0
# titulo araucano                                0
# EGRESADO                                   15244
# título - nombre corto                          0
# AÑO EGRESADO - TITULO                          0
# AÑO-DNI                                        0
# Escuela de Origen                           4839
# Edad durante el año académico                493
# ...

# %%
df = pd.read_excel('arch3.xlsx')
df
# Out:
#       Source.Name  TIPO DOCUMENTO NRO DOCUMENTO  CUIT - CUIL  \
# 0        2019.txt               0      13075985  99999999999
# 1        2019.txt               0      13075985  99999999999
# 2        2019.txt               0      13075985  99999999999
# 3        2019.txt               0      13075985  99999999999
# 4        2019.txt               0      13075985  99999999999
# ...           ...             ...           ...          ...
# 80181    2018.txt               0      42530174  99999999999
# 80182    2018.txt               0      42530174  99999999999
# 80183    2018.txt               0      42587274  99999999999
# 80184    2018.txt               0      42587274  99999999999
# 80185    2018.txt               0      42587274  99999999999
#
#        COD UNIDAD ACADEMICA  COD TITULO  FECHA REGULARIZACION - NO REGULARIZ  \
# 0                      3173         598                             20190701
# ...

# %%
# Dimensions of our dataset
dimensions = df.shape
dimensions
# Out:
# (80186, 42)

# %%
# Data type of each atribute
data_types = df.dtypes
data_types
# Out:
# Source.Name                               object
# TIPO DOCUMENTO                             int64
# NRO DOCUMENTO                             object
# CUIT - CUIL                                int64
# COD UNIDAD ACADEMICA                       int64
# COD TITULO                                 int64
# FECHA REGULARIZACION - NO REGULARIZ        int64
# REGULAR O NO                               int64
# COD INTERNO MATERIA                       object
# NOMBRE MATERIA                            object
# CARGA HORARIA                            float64
# OBLIGATORIEDAD DE LA MATERIA               int64
# FORMA DE REGULARIZACION                    int64
# DEPENDENCIA DE CURSADA                     int64
# LIBRO DE ACTAS                           float64
# NRO DE ACTA                              float64
# FOLIO                                    float64
# EXPEDIENTE                                object
# Año Académico                              int64
# ...

# %%
# Statistical Summary
data_description = df.describe()
data_info = df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 80186 entries, 0 to 80185
# Data columns (total 42 columns):
#  #   Column                                 Non-Null Count  Dtype
# ---  ------                                 --------------  -----
#  0   Source.Name                            80186 non-null  object
#  1   TIPO DOCUMENTO                         80186 non-null  int64
#  2   NRO DOCUMENTO                          80186 non-null  object
#  3   CUIT - CUIL                            80186 non-null  int64
#  4   COD UNIDAD ACADEMICA                   80186 non-null  int64
#  5   COD TITULO                             80186 non-null  int64
#  6   FECHA REGULARIZACION - NO REGULARIZ    80186 non-null  int64
#  7   REGULAR O NO                           80186 non-null  int64
#  8   COD INTERNO MATERIA                    80186 non-null  object
#  9   NOMBRE MATERIA                         79725 non-null  object
# ...

# %%
#Columnas duplicadas
df.duplicated()
# Out:
# 0        False
# 1        False
# 2        False
# 3        False
# 4        False
#          ...
# 80181    False
# 80182    False
# 80183    False
# 80184    False
# 80185    False
# Length: 80186, dtype: bool

# %%
# Corroboremos si tenemos datos faltantes
df.isnull().sum()
# Out:
# Source.Name                                  0
# TIPO DOCUMENTO                               0
# NRO DOCUMENTO                                0
# CUIT - CUIL                                  0
# COD UNIDAD ACADEMICA                         0
# COD TITULO                                   0
# FECHA REGULARIZACION - NO REGULARIZ          0
# REGULAR O NO                                 0
# COD INTERNO MATERIA                          0
# NOMBRE MATERIA                             461
# CARGA HORARIA                            29105
# OBLIGATORIEDAD DE LA MATERIA                 0
# FORMA DE REGULARIZACION                      0
# DEPENDENCIA DE CURSADA                       0
# LIBRO DE ACTAS                            8472
# NRO DE ACTA                               1078
# FOLIO                                     8472
# EXPEDIENTE                               79108
# Año Académico                                0
# Descripción Regular o no                   461
# ...
